# %%
import pandas as pd # library for data analysis
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/List_of_Indian_dishes"
table_class="wikitable sortable  jquery-tablesorter"
table_classb="wikitable sortable north jquery-tablesorter"
table_classc="wikitable sortable south jquery-tablesorter"
table_classd="wikitable sortable west jquery-tablesorter"
table_classe="wikitable sortable east jquery-tablesorter"

response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
indiatable=soup.find('table',{'class':"wikitable"})
indiatable_a=soup.find('table',{'class':"wikitable sortable north"})
indiatable_b=soup.find('table',{'class':"wikitable sortable south"})
indiatable_c=soup.find('table',{'class':"wikitable sortable east"})
indiatable_d=soup.find('table',{'class':"wikitable sortable west"})
indiatable 
indiatable_a
indiatable_b
indiatable_c
indiatable_d
# Out:
# <table class="wikitable sortable west" style="width:100%;">
# <tbody><tr>
# <th><a href="/wiki/Name" title="Name">Name</a></th>
# <th>Image</th>
# <th>Description</th>
# <th>Vegetarian/<br/>Non-Vegetarian
# </th></tr>
# <tr>
# <td>Amti</td>
# <td></td>
# <td>a Lentil curry with Split lentils.</td>
# <td>
# </td></tr>
# <tr>
# <td>Bajri no rotlo</td>
# <td></td>
# <td>Bread made with thick millet flour flatbread usually grilled over coals.</td>
# <td>Vegetarian
# </td></tr>
# <tr>
# <td><a class="new" href="/w/index.php?title=Batata_Saung&amp;action=edit&amp;redlink=1" title="Batata Saung (page does not exist)">Batata Saung</a></td>
# <td></td>
# <td>potato in chilli tamarind gravy.</td>
# <td>Vegetarian
# </td></tr>
# <tr>
# <td><a href="/wiki/Barfi" title="Barfi">Barfi</a></td>
# <td><a class="image" href="/wiki/File:Barfi-Diwali_sweet.jpg"><img alt="Barfi-Diwali sweet.jpg" data-file-height="768" data-file-width="1024" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Barfi-Diwali_sweet.jpg/120px-Barfi-Diwali_sweet.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Barfi-Diwali_sweet.jpg/180px-Barfi-Diwali_sweet.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/72/Barfi-Diwali_sweet.jpg/240px-Barfi-Diwali_sweet.jpg 2x" width="120"/></a></td>
# <td>Sweet</td>
# <td>Vegetarian Desert
# </td></tr>
# <tr>
# <td><a href="/wiki/Basundi" title="Basundi">Basundi</a></td>
# <td></td>
# <td>Sweet made from milk by continuous heating to a point before condensing.</td>
# <td>Vegetarian Desert
# </td></tr>
# <tr>
# <td><a href="/wiki/Bhakri" title="Bhakri">Bhakri</a></td>
# <td><a class="image" href="/wiki/File:Another_Vegetarian_Meal.jpg"><img alt="Another Vegetarian Meal.jpg" data-file-height="1200" data-file-width="1600" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/Another_Vegetarian_Meal.jpg/120px-Another_Vegetarian_Meal.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/Another_Vegetarian_Meal.jpg/180px-Another_Vegetarian_Meal.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e5/Another_Vegetarian_Meal.jpg/240px-Another_Vegetarian_Meal.jpg 2x" width="120"/></a></td>
# <td>Whole wheat flour bread, thicker than rotli, crispy.</td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Bombil_fry" title="Bombil fry">Bombil fry</a></td>
# <td><a class="image" href="/wiki/File:Bombil.jpg"><img alt="Bombil.jpg" data-file-height="1321" data-file-width="2249" decoding="async" height="70" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Bombil.jpg/120px-Bombil.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Bombil.jpg/180px-Bombil.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Bombil.jpg/240px-Bombil.jpg 2x" width="120"/></a></td>
# <td>Main Course; Bombay Duck (Fish).</td>
# <td>Non-Vegetarian
# </td></tr>
# <tr>
# <td><a href="/wiki/Chaat" title="Chaat">Chaat</a></td>
# <td><a class="image" href="/wiki/File:Bhalla_Papri_Chaat_with_saunth_chutney.jpg"><img alt="Bhalla Papri Chaat with saunth chutney.jpg" data-file-height="1024" data-file-width="1013" decoding="async" height="121" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1b/Bhalla_Papri_Chaat_with_saunth_chutney.jpg/120px-Bhalla_Papri_Chaat_with_saunth_chutney.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1b/Bhalla_Papri_Chaat_with_saunth_chutney.jpg/180px-Bhalla_Papri_Chaat_with_saunth_chutney.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1b/Bhalla_Papri_Chaat_with_saunth_chutney.jpg/240px-Bhalla_Papri_Chaat_with_saunth_chutney.jpg 2x" width="120"/></a></td>
# <td>Snack</td>
# <td>Vegetarian
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Chevdo" title="Chevdo">Chevdo</a></td>
# <td><a class="image" href="/wiki/File:Bombaymix.jpg"><img alt="Bombaymix.jpg" data-file-height="686" data-file-width="760" decoding="async" height="108" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c6/Bombaymix.jpg/120px-Bombaymix.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c6/Bombaymix.jpg/180px-Bombaymix.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c6/Bombaymix.jpg/240px-Bombaymix.jpg 2x" width="120"/></a></td>
# <td>Mixture of Flattened rice, groundnut, chana, masala.</td>
# <td>
# </td></tr>
# <tr>
# <td>Cholafali</td>
# <td></td>
# <td>snack</td>
# <td>
# </td></tr>
# <tr>
# <td>Chorafali</td>
# <td></td>
# <td>Spicy. Ground chana dal and urad dal, deep fried flattened disk, masala, sprinkle with red chili powder on top.</td>
# <td>
# </td></tr>
# <tr>
# <td>Daal Dhokli</td>
# <td></td>
# <td>Daal Dhokli is widely cooked and eaten all over Rajasthan and Gujarat. Very small dumplings of wheat flour are cooked along with green gram or pegeon dal and whole red chili and red mustard is used as tempering.</td>
# <td>Vegetarian
# </td></tr>
# <tr>
# <td><a href="/wiki/Dabeli" title="Dabeli">Dabeli</a>
# </td>
# <td><div class="thumb tright"><div class="thumbinner" style="width:222px;"><a class="image" href="/wiki/File:Dabeli.jpg"><img alt="Kutchi dabeli" class="thumbimage" data-file-height="333" data-file-width="500" decoding="async" height="147" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Dabeli.jpg/220px-Dabeli.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Dabeli.jpg/330px-Dabeli.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/63/Dabeli.jpg/440px-Dabeli.jpg 2x" width="220"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Dabeli.jpg" title="Enlarge"></a></div>Kutchi dabeli</div></div></div>
# </td>
# <td>Snack made by mixing boiled potatoes with a special dabeli <a href="/wiki/Spice_mix#Masala" title="Spice mix">masala</a>, putting the mixture in a <i>ladi pav</i>
# </td>
# <td>Vegetarian
# </td></tr>
# <tr>
# <td><a href="/wiki/Dahi_vada" title="Dahi vada">Dahi vada</a></td>
# <td><a class="image" href="/wiki/File:Dahi_Vadas_(Dhai_Bhalla).JPG"><img alt="Dahi Vadas (Dhai Bhalla).JPG" data-file-height="3672" data-file-width="4896" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Dahi_Vadas_%28Dhai_Bhalla%29.JPG/120px-Dahi_Vadas_%28Dhai_Bhalla%29.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Dahi_Vadas_%28Dhai_Bhalla%29.JPG/180px-Dahi_Vadas_%28Dhai_Bhalla%29.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/34/Dahi_Vadas_%28Dhai_Bhalla%29.JPG/240px-Dahi_Vadas_%28Dhai_Bhalla%29.JPG 2x" width="120"/></a></td>
# <td>Fried lentil balls in a yogurt sauce. Lentils, yogurt.</td>
# <td>Vegetarian
# </td></tr>
# <tr>
# <td><a href="/wiki/Dalithoy" title="Dalithoy">Dalithoy</a></td>
# <td></td>
# <td>Soup made with split yellow lentils.</td>
# <td>Vegetarian
# </td></tr>
# <tr>
# <td><a href="/wiki/Dhokla" title="Dhokla">Dhokla</a></td>
# <td><a class="image" href="/wiki/File:Khaman_dhokla.jpg"><img alt="Khaman dhokla.jpg" data-file-height="600" data-file-width="1100" decoding="async" height="65" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/08/Khaman_dhokla.jpg/120px-Khaman_dhokla.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/08/
jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6d/Komdi_vade.jpg/240px-Komdi_vade.jpg 2x" width="120"/></a></td>
# <td>Chicken Curry with Bread. Chicken.</td>
# <td>
# </td></tr>
# <tr>
# <td>Kopra paak</td>
# <td></td>
# <td>Sweet coconut halwa/barfi: Halwa is soft, barfi more like cake.</td>
# <td>
# </td></tr>
# <tr>
# <td>Koshimbir</td>
# <td></td>
# <td>a salad, usually served as a side</td>
# <td>
# </td></tr>
# <tr>
# <td>Kolim / Jawla</td>
# <td></td>
# <td>A preparation of dried fish named Kolim or Jawla found in coastal Maharashtra with onion and spices. Usually eaten with bhakri or chapati</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Laapsi" title="Laapsi">Laapsi</a></td>
# <td></td>
# <td>Sweet coarse ground/ broken wheat cooked with butter and sugar.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Laddu" title="Laddu">Laddu</a></td>
# <td><a class="image" href="/wiki/File:Laddu1.JPG"><img alt="Laddu1.JPG" data-file-height="3000" data-file-width="4000" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/46/Laddu1.JPG/120px-Laddu1.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/46/Laddu1.JPG/180px-Laddu1.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/46/Laddu1.JPG/240px-Laddu1.JPG 2x" width="120"/></a></td>
# <td>Sweet</td>
# <td>
# </td></tr>
# <tr>
# <td>Locha</td>
# <td></td>
# <td>Surat (Gujarat) special Spicy dish. Ground chanadal, masala.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Malpua" title="Malpua">Malpua</a></td>
# <td><a class="image" href="/wiki/File:Malapua_Odia_cuisine.jpg"><img alt="Malapua Odia cuisine.jpg" data-file-height="498" data-file-width="840" decoding="async" height="71" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Malapua_Odia_cuisine.jpg/120px-Malapua_Odia_cuisine.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Malapua_Odia_cuisine.jpg/180px-Malapua_Odia_cuisine.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Malapua_Odia_cuisine.jpg/240px-Malapua_Odia_cuisine.jpg 2x" width="120"/></a></td>
# <td>Sweet</td>
# <td>
# </td></tr>
# <tr>
# <td>Methi na Gota</td>
# <td></td>
# <td>Snack. Fried fenugreek dumplings.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Modak" title="Modak">Modak</a></td>
# <td></td>
# <td>A Marathi sweet dish made of steamed rice flour with coconut and jaggery filling</td>
# <td>Vegetarian Desert
# </td></tr>
# <tr>
# <td>Mohanthal</td>
# <td></td>
# <td>a sweet prepared from gram flour and ghee dry fruits</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Murukku" title="Murukku">Chakri</a> (chakali)</td>
# <td><a class="image" href="/wiki/File:Chakali.JPG"><img alt="Chakali.JPG" data-file-height="2112" data-file-width="2816" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Chakali.JPG/120px-Chakali.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Chakali.JPG/180px-Chakali.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Chakali.JPG/240px-Chakali.JPG 2x" width="120"/></a></td>
# <td>a Savoury snack. Mixed grain flour.</td>
# <td>Vegetarian
# </td></tr>
# <tr>
# <td>Muthiya</td>
# <td></td>
# <td>Gujarati Snack. Whole wheat flour, methi leaves, besan/chickpeas flour and coriander leaves/cilantro.</td>
# <td>
# </td></tr>
# <tr>
# <td>Naralachi vadi / Khobryachi vadi / Coconut vadi</td>
# <td></td>
# <td>A sweet made of coconut and sugar syrup which is cooled and dried till it becomes firm. Usually made in konkan region</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Oondees" title="Oondees">Oondees</a></td>
# <td></td>
# <td>Breakfast delicacy. Spherical shaped rice or semolina about four inches (10 cm) in diameter.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Panipuri" title="Panipuri">Panipuri</a></td>
# <td><a class="image" href="/wiki/File:Indian_cuisine-Panipuri-03.jpg"><img alt="Indian cuisine-Panipuri-03.jpg" data-file-height="2304" data-file-width="3456" decoding="async" height="80" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/22/Indian_cuisine-Panipuri-03.jpg/120px-Indian_cuisine-Panipuri-03.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/22/Indian_cuisine-Panipuri-03.jpg/180px-Indian_cuisine-Panipuri-03.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/22/Indian_cuisine-Panipuri-03.jpg/240px-Indian_cuisine-Panipuri-03.jpg 2x" width="120"/></a></td>
# <td>Snack</td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/
</td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Sabudana_Khichadi" title="Sabudana Khichadi">Sabudana Khichadi</a></td>
# <td></td>
# <td>Vegetarian Snack. Sago.</td>
# <td>
# </td></tr>
# <tr>
# <td>Saath</td>
# <td></td>
# <td>A chewy plain flat circular sweet made of dried mango (sometimes jackfruit) juice/pulp.
# <p>Usually made in Konkan region of Maharashtra ||
# </p>
# </td></tr>
# <tr>
# <td>Sev khamani</td>
# <td></td>
# <td>Chana dal, green chillies, ginger, lemon juice and olive oil.</td>
# <td>
# </td></tr>
# <tr>
# <td>Sev tameta</td>
# <td></td>
# <td>Veggis with potatoes and sev.</td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Shakarpara" title="Shakarpara">Shakarpara</a></td>
# <td></td>
# <td>A deep fried snack made out of sugar and wheat.</td>
# <td>
# </td></tr>
# <tr>
# <td><a class="new" href="/w/index.php?title=Namakpara&amp;action=edit&amp;redlink=1" title="Namakpara (page does not exist)">Namakpara</a></td>
# <td></td>
# <td>Snack. A deep fried snack made out of salt and Gram Flour .</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Shankarpali" title="Shankarpali">Shankarpali</a></td>
# <td><a class="image" href="/wiki/File:Shankarpali_sweets_mithai_Western_India_2012.jpg"><img alt="Shankarpali sweets mithai Western India 2012.jpg" data-file-height="2602" data-file-width="3903" decoding="async" height="80" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/55/Shankarpali_sweets_mithai_Western_India_2012.jpg/120px-Shankarpali_sweets_mithai_Western_India_2012.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/55/Shankarpali_sweets_mithai_Western_India_2012.jpg/180px-Shankarpali_sweets_mithai_Western_India_2012.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/55/Shankarpali_sweets_mithai_Western_India_2012.jpg/240px-Shankarpali_sweets_mithai_Western_India_2012.jpg 2x" width="120"/></a></td>
# <td>Sweet or savoury snack. Plain flour, sugar.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Shiro_(food)" title="Shiro (food)">Shiro</a></td>
# <td><a class="image" href="/wiki/File:Taita_and_shiro.jpg"><img alt="Taita and shiro.jpg" data-file-height="679" data-file-width="1112" decoding="async" height="73" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Taita_and_shiro.jpg/120px-Taita_and_shiro.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Taita_and_shiro.jpg/180px-Taita_and_shiro.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Taita_and_shiro.jpg/240px-Taita_and_shiro.jpg 2x" width="120"/></a></td>
# <td>Sweet roasted semolina/flour/dal with milk, butter, sugar, nuts and raisins.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Shrikhand" title="Shrikhand">Shrikhand</a></td>
# <td><a class="image" href="/wiki/File:Shrikhand_london_kastoori.jpg"><img alt="Shrikhand london kastoori.jpg" data-file-height="920" data-file-width="1256" decoding="async" height="88" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Shrikhand_london_kastoori.jpg/120px-Shrikhand_london_kastoori.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Shrikhand_london_kastoori.jpg/180px-Shrikhand_london_kastoori.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Shrikhand_london_kastoori.jpg/240px-Shrikhand_london_kastoori.jpg 2x" width="120"/></a></td>
# <td>A thick yogurt-based sweet dessert garnished with ground nuts, cardamom, and saffron.</td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Sohan_papdi" title="Sohan papdi">Sohan papdi</a></td>
# <td><a class="image" href="/wiki/File:Soanpapdi.JPG"><img alt="Soanpapdi.JPG" data-file-height="1600" data-file-width="1200" decoding="async" height="160" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/03/Soanpapdi.JPG/120px-Soanpapdi.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/03/Soanpapdi.JPG/180px-Soanpapdi.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/03/Soanpapdi.JPG/240px-Soanpapdi.JPG 2x" width="120"/></a></td>
# <td>Sweet</td>
# <td>
# </td></tr>
# <tr>
# <td>Soonvali</td>
# <td></td>
# <td>Snack</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Sukhdi" title="Sukhdi">Sukhdi</a></td>
# <td><a class="image" href="/wiki/File:Sukhdi.jpg"><img alt="Sukhdi.jpg" data-file-height="250" data-file-width="240" decoding="async" height="125" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Sukhdi.jpg/120px-Sukhdi.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Sukhdi.jpg/180px-Sukhdi.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/f/f9/Sukhdi.jpg 2x" width="120"/></a></td>
# <td>Sweet</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Surnoli" title="Surnoli">Surnoli</a></td>
# <td></td>
# <td>Pancakes that have holes. are yellow and puffy.  They are about 10 inches (25 centimeters) in diameter and often served with butter.
# </td></tr>
# <tr>
# <td><a href="/wiki/Sutarfeni" title="Sutarfeni">Sutarfeni</a></td>
# <td></td>
# <td>Sweet</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Thalipeeth" title="Thalipeeth">Thalipeeth</a></td>
# <td></td>
# <td>Savoury pancake. Mixed grain flour.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Thepla" title="Thepla">Thepla</a></td>
# <td></td>
# <td>Paratha. Mixed grain flour.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Undhiyu" title="Undhiyu">Undhiyu</a></td>
# <td></td>
# <td>Mix veggi. Plantain, brinjal, carrot, green chillies, potatoes, fresh coconut and other vegetables. Gujarati food.</td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Upmaa" title="Upmaa">Upmaa</a></td>
# <td><a class="image" href="/wiki/File:Upma.jpg"><img alt="Upma.jpg" data-file-height="1168" data-file-width="1760" decoding="async" height="80" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/16/Upma.jpg/120px-Upma.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/16/Upma.jpg/180px-Upma.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/16/Upma.jpg/240px-Upma.jpg 2x" width="120"/></a></td>
# <td>a dish originating from the Indian subcontinent, cooked as a thick porridge from dry-roasted semolina or coarse rice flour.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Vada_pav" title="Vada pav">Vada pav</a></td>
# <td><a class="image" href="/wiki/File:Jumbo_Vada_Pav_(dodged).jpg"><img alt="Jumbo Vada Pav (dodged).jpg" data-file-height="1056" data-file-width="1408" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/40/Jumbo_Vada_Pav_%28dodged%29.jpg/120px-Jumbo_Vada_Pav_%28dodged%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/40/Jumbo_Vada_Pav_%28dodged%29.jpg/180px-Jumbo_Vada_Pav_%28dodged%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/40/Jumbo_Vada_Pav_%28dodged%29.jpg/240px-Jumbo_Vada_Pav_%28dodged%29.jpg 2x" width="120"/></a></td>
# <td>Burger. Gram flour, potatoes, chilli, garlic, ginger.</td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Veg_Kolhapuri" title="Veg Kolhapuri">Veg Kolhapuri</a></td>
# <td></td>
# <td>Mixed vegetables.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Vindaloo" title="Vindaloo">Vindaloo</a></td>
# <td><a class="image" href="/wiki/File:Vindalho.jpg"><img alt="Vindalho.jpg" data-file-height="480" data-file-width="640" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/28/Vindalho.jpg/120px-Vindalho.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/28/Vindalho.jpg/180px-Vindalho.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/28/Vindalho.jpg/240px-Vindalho.jpg 2x" width="120"/></a></td>
# <td>Goan pork vindaloo. Pork, goan red chilli paste.</td>
# <td>
# </td></tr>
# <tr>
# <td>Ghebar or <a href="/wiki/Ghevar" title="Ghevar">Ghevar</a></td>
# <td><a class="image" href="/wiki/File:GhevarRajasthaniSweet.jpg"><img alt="GhevarRajasthaniSweet.jpg" data-file-height="1087" data-file-width="1161" decoding="async" height="112" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a7/GhevarRajasthaniSweet.jpg/120px-GhevarRajasthaniSweet.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a7/GhevarRajasthaniSweet.jpg/180px-GhevarRajasthaniSweet.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a7/GhevarRajasthaniSweet.jpg/240px-GhevarRajasthaniSweet.jpg 2x" width="120"/></a></td>
# <td>Sweet from Surat</td>
# <td>
# </td></tr>
# <tr>
# <td>Lilva <a href="/wiki/Kachori" title="Kachori">Kachori</a></td>
# <td><a class="image" href="/wiki/File:Cachuri2_flipped.jpg"><img alt="Cachuri2 flipped.jpg" data-file-height="450" data-file-width="600" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Cachuri2_flipped.jpg/120px-Cachuri2_flipped.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Cachuri2_flipped.jpg/180px-Cachuri2_flipped.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Cachuri2_flipped.jpg/240px-Cachuri2_flipped.jpg 2x" width="120"/></a></td>
# <td>Snack. Lilva and whole wheat flour.</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Maghaz" title="Maghaz">Maghaz</a></td>
# <td><a class="image" href="/wiki/File:Magaj.jpg"><img alt="Magaj.jpg" data-file-height="1200" data-file-width="1600" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Magaj.jpg/120px-Magaj.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Magaj.jpg/180px-Magaj.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Magaj.jpg/240px-Magaj.jpg 2x" width="120"/></a></td>
# <td></td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Undhiyu" title="Undhiyu">Undhiyu</a></td>
# <td></td>
# <td>The signature winter Gujarati dish. Curry of mixed vegetables like surti papdi, ratalu, potatoes, carrot, green garlic, tuvar dana, waal dana etc. rich in oil and spices generally accompanied by puri or roti.
# </td></tr>
# <tr>
# <td><a class="new" href="/w/index.php?title=Mag_Dhokli&amp;action=edit&amp;redlink=1" title="Mag Dhokli (page does not exist)">Mag Dhokli</a></td>
# <td></td>
# <td>an Indian dish made of lentils and fresh dough with Indian spices, it is dry and not liquidy like daal dhokli.
# </td></tr>
# <tr>
# <td><a href="/wiki/Khichu" title="Khichu">Khichu</a></td>
# <td></td>
# <td>It is made by boiling the rice flour in water with seasoning, subtle in taste and accompanied by oil and methi masala.
# </td></tr>
# <tr>
# <td><a href="/wiki/Thepla" title="Thepla">Thepla</a></td>
# <td></td>
# <td>A signature Gujarati snack which is a parantha with seasoning, made from wheat flour, this dish is generally accompanied by condiments like pickles, green chillies, etc. It is also known as Dhebra, Chopda etc. in various regions.
# </td></tr>
# <tr>
# <td><a class="new" href="/w/index.php?title=Farsi_Puri&amp;action=edit&amp;redlink=1" title="Farsi Puri (page does not exist)">Farsi Puri</a></td>
# <td></td>
# <td>It is a Gujarati snack which is also known as mathri in other regions of India, it generally made from wheat flour, all purpose flour etc.
# </td></tr>
# <tr>
# <td><a href="/wiki/Khaman" title="Khaman">Khaman</a></td>
# <td></td>
# <td>Made by steaming gram flour batter with flavorful seasoning accompanied with chutney.
# </td></tr>
# <tr>
# <td><a class="new" href="/w/index.php?title=Turiya_Patra_Vatana_sabji&amp;action=edit&amp;redlink=1" title="Turiya Patra Vatana sabji (page does not exist)">Turiya Patra Vatana sabji</a></td>
# <td></td>
# <td>A vegetable curry made generally in winters.
# </td></tr>
# <tr>
# <td><a class="new" href="/w/index.php?title=Mohan_thaal&amp;action=edit&amp;redlink=1" title="Mohan thaal (page does not exist)">Mohan thaal</a></td>
# <td></td>
# <td>A sweet dish.
# </td></tr>
# <tr>
# <td><a class="new" href="/w/index.php?title=Churma_Ladoo&amp;action=edit&amp;redlink=1" title="Churma Ladoo (page does not exist)">Churma Ladoo</a></td>
# <td></td>
# <td>A sweet dish made with wheat flour, ghee, sugar or jaggery and dry fruits.
# </td></tr></tbody></table>

# %%
df=pd.read_html(str(indiatable))
df_a=pd.read_html(str(indiatable_a))
df_b=pd.read_html(str(indiatable_b))
df_c=pd.read_html(str(indiatable_c))
df_d=pd.read_html(str(indiatable_d))
# convert list to dataframe
df=pd.DataFrame(df[0])
df_a=pd.DataFrame(df_a[0])
df_b=pd.DataFrame(df_b[0])
df_c=pd.DataFrame(df_c[0])
df_d=pd.DataFrame(df_d[0])
print(df.head())
print(df_a.head(n=90))
print(df_b.head(n=66))
print(df_c.head(n=61))
print(df_d.head(n=93))
# Out:
#              Name  Image                                        Description  \
# 0      Maach Jhol    NaN  Fish with potol, tomato, chillies, ginger and ...
# 1     Pork Bharta    NaN  Boiled pork with onions, chillies, ginger and ...
# 2  Chak-Hao Kheer    NaN                  Purple rice porridge from Manipur
# 3           Galho    NaN  Galho is similar to khichdi, a dish made from ...
#
#   Vegetarian/Non-Vegetarian
# 0         Non-Vegetarian[1]
# 1         Non-Vegetarian[1]
# 2             Vegetarian[1]
# 3                Vegetarian
#                                         Name Image  \
# 0                                  Aloo gobi   NaN
# 1                                 Aloo tikki   NaN
# 2                                   Aloo tuk   NaN
# 3                                 Aloo matar   NaN
# 4                                 Aloo methi   NaN
# ..                                       ...   ...
# 85                               Sooji halwa   NaN
# 86  Sweet pethas / kesar petha / pista petha   NaN
# 87                        Vegetable jalfrezi   NaN
# 88                          Tandoori Chicken   NaN
# 89                       Tandoori Fish Tikka   NaN
#
#                                           Description  \
# 0   Cauliflower with potatoes sautéed with garam m...
# 1   Patties of potato mixed with some vegetables f...
# 2              double fried potatoes tossed in spices
# 3                          Potatoes and peas in curry
# 4                     Potato with fresh Methi leaves.
# ..                                                ...
# 85  Semolina cooked with clarified butter and dry ...
# 86  A ravioli like dessert stuffed with a choice o...
# 87  Meat and spices fried in a pan. Can be vegetar...
# 88  Tandoori chicken as a dish originated in the P...
# 89  Fish marinated in lime and ginger and cooked o...
#
#    Vegetarian/Non-Vegetarian
# 0                 Vegetarian
# 1                 Vegetarian
# 2                 Vegeterian
# 3                 Vegetarian
# 4                 Vegetarian
# ..                       ...
# 85                Vegetarian
# 86                Vegetarian
# 87                Vegetarian
# 88            Non-Vegetarian
# 89                       NaN
#
# [90 rows x 4 columns]
#                            Name Image  \
# 0                          Attu   NaN
# 1                         Avial   NaN
# 2                         Halwa   NaN
# 3                        Bhajji   NaN
# 4                       Biryani   NaN
# ..                          ...   ...
# 61           Uttapam Tamil Nadu   NaN
# 62                         Vada   NaN
# 63                      Varuval   NaN
# 64          Wheat upma, Uppittu   NaN
# 65  Yelumicham sadam, chitranna   NaN
#
#                                           Description  \
# 0   Several types are made with several type of fl...
# 1   Coconut paste, curd mixed with vegetables and ...
# 2   Maida or Sugarcane fritters which are known as...
# 3   Vegetable or onion fritters which are known as...
# 4   Spicy rice dish with vegetables or chicken or ...
# ..                                                ...
# 61  Rice pancake/hopper with a topping of onions /...
# 62                            Savory donut. Urad dal.
# 63                    Vegetables fried in shallow oil
# 64  A breakfast dish and snack. Upma prepared from...
# 65                              Rice with lemon juice
#
#    Vegetarian/Non-Vegetarian                       Dish Type
# 0                 Vegetarian                             NaN
# 1                 Vegetarian  Accompaniment with Staple food
# 2                 Vegetarian                   Sweet/Dessert
# 3                 Vegetarian       Snack/ meal accompaniment
# 4          Depends on choice                             NaN
# ..                       ...                             ...
# 61                Vegetarian                  Breakfast dish
# 62                Vegetarian                   accompaniment
# 63                Vegetarian                   accompaniment
# 64                Vegetarian                  Breakfast dish
# 65                Vegetarian                  Breakfast dish
#
# [66 rows x 5 columns]
#             Name                   Image  \
# 0     Cheera Doi                     NaN
# 1   Daab chingri  daab chingri with rice
# 2     Dhup Pitha                     NaN
# 3   Gheela Pitha                     NaN
# 4          Hurum                     NaN
# ..           ...                     ...
# 56      Shondesh                     NaN
# 57        Shukto                     NaN
# 58    Sunga Pork                     NaN
# 59     Tenga Doi                     NaN
# 60     Til Pitha                     NaN
#
#                                           Description  \
# 0                                 A breakfast cereal.
# 1                 prawn curry cooked in green coconut
# 2                          A sweet Assamese specialty
# 3                          A Sweet Assamese specialty
# 4           A Breakfast cereal; an Assamese specialty
# ..                                                ...
# 56  A dessert with milk and sugar. A signature Ben...
# 57  A Bengali cuisine. Diced potatoes, sweet potat...
# 58                              Rich spicy pork curry
# 59                                          Sour curd
# 60  A sweet Assamese specialty. Rice powder, til, ...
#
#    Vegetarian/Non-Vegetarian
# 0                 Vegetarian
# 1             Non-vegetarian
# 2                      Sweet
# 3                      Sweet
# 4                        NaN
# ..                       ...
# 56                       NaN
# 57                       NaN
# 58                       NaN
# 59                       NaN
# 60                       NaN
#
# [61 rows x 4 columns]
#                          Name Image  \
# 0                        Amti   NaN
# 1              Bajri no rotlo   NaN
# 2                Batata Saung   NaN
# 3                       Barfi   NaN
# 4                     Basundi   NaN
# ..                        ...   ...
# 88                 Farsi Puri   NaN
# 89                     Khaman   NaN
# 90  Turiya Patra Vatana sabji   NaN
# 91                Mohan thaal   NaN
# 92               Churma Ladoo   NaN
#
#                                           Description  \
# 0                  a Lentil curry with Split lentils.
# 1   Bread made with thick millet flour flatbread u...
# 2                    potato in chilli tamarind gravy.
# 3                                               Sweet
# 4   Sweet made from milk by continuous heating to ...
# ..                                                ...
# 88  It is a Gujarati snack which is also known as ...
# 89  Made by steaming gram flour batter with flavor...
# 90       A vegetable curry made generally in winters.
# 91                                      A sweet dish.
# 92  A sweet dish made with wheat flour, ghee, suga...
#
#    Vegetarian/Non-Vegetarian
# 0                        NaN
# 1                 Vegetarian
# 2                 Vegetarian
# 3          Vegetarian Desert
# 4          Vegetarian Desert
# ..                       ...
# 88                       NaN
# 89                       NaN
# 90                       NaN
# 91                       NaN
# 92                       NaN
#
# [93 rows x 4 columns]

# %%
# drop the unwanted columns
data = df.drop(["Image", "Description"], axis=1)
data.head()
# Out:
#              Name Vegetarian/Non-Vegetarian
# 0      Maach Jhol         Non-Vegetarian[1]
# 1     Pork Bharta         Non-Vegetarian[1]
# 2  Chak-Hao Kheer             Vegetarian[1]
# 3           Galho                Vegetarian

# %%
data_a = df_a.drop(["Image", "Description"], axis=1)
data_a.head(90)
# Out:
#                                         Name Vegetarian/Non-Vegetarian
# 0                                  Aloo gobi                Vegetarian
# 1                                 Aloo tikki                Vegetarian
# 2                                   Aloo tuk                Vegeterian
# 3                                 Aloo matar                Vegetarian
# 4                                 Aloo methi                Vegetarian
# ..                                       ...                       ...
# 85                               Sooji halwa                Vegetarian
# 86  Sweet pethas / kesar petha / pista petha                Vegetarian
# 87                        Vegetable jalfrezi                Vegetarian
# 88                          Tandoori Chicken            Non-Vegetarian
# 89                       Tandoori Fish Tikka                       NaN
#
# [90 rows x 2 columns]

# %%
data_b = df_b.drop(["Image", "Description"], axis=1)
data_b.head(66)
# Out:
#                            Name Vegetarian/Non-Vegetarian  \
# 0                          Attu                Vegetarian
# 1                         Avial                Vegetarian
# 2                         Halwa                Vegetarian
# 3                        Bhajji                Vegetarian
# 4                       Biryani         Depends on choice
# ..                          ...                       ...
# 61           Uttapam Tamil Nadu                Vegetarian
# 62                         Vada                Vegetarian
# 63                      Varuval                Vegetarian
# 64          Wheat upma, Uppittu                Vegetarian
# 65  Yelumicham sadam, chitranna                Vegetarian
#
#                          Dish Type
# 0                              NaN
# 1   Accompaniment with Staple food
# 2                    Sweet/Dessert
# 3        Snack/ meal accompaniment
# 4                              NaN
# ..                             ...
# 61                  Breakfast dish
# 62                   accompaniment
# 63                   accompaniment
# 64                  Breakfast dish
# 65                  Breakfast dish
#
# [66 rows x 3 columns]

# %%
data_c = df_c.drop(["Image", "Description"], axis=1)
data_c.head(61)
# Out:
#             Name Vegetarian/Non-Vegetarian
# 0     Cheera Doi                Vegetarian
# 1   Daab chingri            Non-vegetarian
# 2     Dhup Pitha                     Sweet
# 3   Gheela Pitha                     Sweet
# 4          Hurum                       NaN
# ..           ...                       ...
# 56      Shondesh                       NaN
# 57        Shukto                       NaN
# 58    Sunga Pork                       NaN
# 59     Tenga Doi                       NaN
# 60     Til Pitha                       NaN
#
# [61 rows x 2 columns]

# %%
data_d = df_d.drop(["Image", "Description"], axis=1)
data_d.head(93)
# Out:
#                          Name Vegetarian/Non-Vegetarian
# 0                        Amti                       NaN
# 1              Bajri no rotlo                Vegetarian
# 2                Batata Saung                Vegetarian
# 3                       Barfi         Vegetarian Desert
# 4                     Basundi         Vegetarian Desert
# ..                        ...                       ...
# 88                 Farsi Puri                       NaN
# 89                     Khaman                       NaN
# 90  Turiya Patra Vatana sabji                       NaN
# 91                Mohan thaal                       NaN
# 92               Churma Ladoo                       NaN
#
# [93 rows x 2 columns]

# %%
frames = [data,data_a, data_b, data_c,data_d]
result = pd.concat(frames)
result.reset_index(level=None, drop=True, inplace=True, col_level=0, col_fill='')
result.head(314)
# Out:
#                           Name Vegetarian/Non-Vegetarian Dish Type
# 0                   Maach Jhol         Non-Vegetarian[1]       NaN
# 1                  Pork Bharta         Non-Vegetarian[1]       NaN
# 2               Chak-Hao Kheer             Vegetarian[1]       NaN
# 3                        Galho                Vegetarian       NaN
# 4                    Aloo gobi                Vegetarian       NaN
# ..                         ...                       ...       ...
# 309                 Farsi Puri                       NaN       NaN
# 310                     Khaman                       NaN       NaN
# 311  Turiya Patra Vatana sabji                       NaN       NaN
# 312                Mohan thaal                       NaN       NaN
# 313               Churma Ladoo                       NaN       NaN
#
# [314 rows x 3 columns]

# %%
result.to_csv('Food_of_India_Dataset.csv', index=1)
#https://www.kaggle.com/eemanmajumder/list-of-indian-food/
